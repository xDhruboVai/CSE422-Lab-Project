# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import Sequential, layers, callbacks, optimizers
from sklearn.utils.class_weight import compute_class_weight

# %%
X_train_scaled = pd.read_csv("/Users/dihanislamdhrubo/Downloads/CSE422-Lab-Project-main/data/X_train_scaled.csv")
X_test_scaled = pd.read_csv("/Users/dihanislamdhrubo/Downloads/CSE422-Lab-Project-main/data/X_test_scaled.csv")
X_train = pd.read_csv("/Users/dihanislamdhrubo/Downloads/CSE422-Lab-Project-main/data/X_train.csv")
X_test = pd.read_csv("/Users/dihanislamdhrubo/Downloads/CSE422-Lab-Project-main/data/X_test.csv")
y_train = pd.read_csv("/Users/dihanislamdhrubo/Downloads/CSE422-Lab-Project-main/data/y_train.csv")
y_test = pd.read_csv("/Users/dihanislamdhrubo/Downloads/CSE422-Lab-Project-main/data/y_test.csv")

# %%
num_features = X_train_scaled.shape[1]
num_classes  = np.unique(y_train).size

# %%
model = Sequential([
    layers.Input(shape = (num_features,)),

    #layers.Dense(512, activation = 'relu'),
    #layers.BatchNormalization(),
    #layers.Dropout(0.3),
    
    layers.Dense(256, activation = 'relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),

    layers.Dense(128, activation = 'relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),

    layers.Dense(64, activation = 'relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),

    layers.Dense(32, activation = 'relu'),
    layers.Dense(num_classes, activation = 'softmax')  # multiclass output
])

# %%
model.compile(
    optimizer = optimizers.Adam(learning_rate = 1e-3),
    loss = 'sparse_categorical_crossentropy',
    metrics = ['accuracy']
)

# %%
early_stop = callbacks.EarlyStopping(
    monitor = 'val_loss', patience = 10, restore_best_weights = True
)
reduce_lr = callbacks.ReduceLROnPlateau(
    monitor = 'val_loss', factor = 0.5, patience = 3
)

# %%
history = model.fit(
    X_train_scaled, y_train,
    validation_data = (X_test_scaled, y_test),
    epochs = 100,
    batch_size = 256,
    callbacks = [early_stop, reduce_lr],
)
# Out:
# Epoch 1/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.2092 - loss: 2.2051 - val_accuracy: 0.3044 - val_loss: 1.8827 - learning_rate: 0.0010
# Epoch 2/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3521 - loss: 1.7386 - val_accuracy: 0.4890 - val_loss: 1.8044 - learning_rate: 0.0010
# Epoch 3/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4096 - loss: 1.5076 - val_accuracy: 0.5016 - val_loss: 1.7306 - learning_rate: 0.0010
# Epoch 4/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5064 - loss: 1.3654 - val_accuracy: 0.4984 - val_loss: 1.6671 - learning_rate: 0.0010
# Epoch 5/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5342 - loss: 1.2339 - val_accuracy: 0.5142 - val_loss: 1.6062 - learning_rate: 0.0010
# Epoch 6/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5674 - loss: 1.1432 - val_accuracy: 0.5426 - val_loss: 1.5440 - learning_rate: 0.0010
# Epoch 7/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6141 - loss: 1.0420 - val_accuracy: 0.5852 - val_loss: 1.4810 - learning_rate: 0.0010
# Epoch 8/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6405 - loss: 0.9782 - val_accuracy: 0.6246 - val_loss: 1.4130 - learning_rate: 0.0010
# Epoch 9/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6601 - loss: 0.9112 - val_accuracy: 0.6546 - val_loss: 1.3426 - learning_rate: 0.0010
# Epoch 10/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6913 - loss: 0.8391 - val_accuracy: 0.6703 - val_loss: 1.2723 - learning_rate: 0.0010
# Epoch 11/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6899 - loss: 0.8124 - val_accuracy: 0.6830 - val_loss: 1.2024 - learning_rate: 0.0010
# Epoch 12/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7183 - loss: 0.7533 - val_accuracy: 0.7145 - val_loss: 1.1370 - learning_rate: 0.0010
# Epoch 13/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7427 - loss: 0.6872 - val_accuracy: 0.7319 - val_loss: 1.0771 - learning_rate: 0.0010
# Epoch 14/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7481 - loss: 0.6624 - val_accuracy: 0.7382 - val_loss: 1.0268 - learning_rate: 0.0010
# Epoch 15/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7691 - loss: 0.6153 - val_accuracy: 0.7382 - val_loss: 0.9772 - learning_rate: 0.0010
# Epoch 16/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7766 - loss: 0.5877 - val_accuracy: 0.7366 - val_loss: 0.9363 - learning_rate: 0.0010
# Epoch 17/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7915 - loss: 0.5634 - val_accuracy: 0.7429 - val_loss: 0.8939 - learning_rate: 0.0010
# Epoch 18/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8172 - loss: 0.5126 - val_accuracy: 0.7413 - val_loss: 0.8569 - learning_rate: 0.0010
# Epoch 19/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7996 - loss: 0.4998 - val_accuracy: 0.7319 - val_loss: 0.8273 - learning_rate: 0.0010
# Epoch 20/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8233 - loss: 0.4709 - val_accuracy: 0.7334 - val_loss: 0.7993 - learning_rate: 0.0010
# Epoch 21/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8314 - loss: 0.4489 - val_accuracy: 0.7492 - val_loss: 0.7709 - learning_rate: 0.0010
# Epoch 22/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8382 - loss: 0.4311 - val_accuracy: 0.7776 - val_loss: 0.7432 - learning_rate: 0.0010
# Epoch 23/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8531 - loss: 0.4130 - val_accuracy: 0.7760 - val_loss: 0.7297 - learning_rate: 0.0010
# Epoch 24/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8571 - loss: 0.3909 - val_accuracy: 0.7823 - val_loss: 0.7003 - learning_rate: 0.0010
# Epoch 25/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8585 - loss: 0.3710 - val_accuracy: 0.7539 - val_loss: 0.6846 - learning_rate: 0.0010
# Epoch 26/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8700 - loss: 0.3599 - val_accuracy: 0.7555 - val_loss: 0.6614 - learning_rate: 0.0010
# Epoch 27/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8680 - loss: 0.3510 - val_accuracy: 0.7666 - val_loss: 0.6434 - learning_rate: 0.0010
# Epoch 28/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8890 - loss: 0.3336 - val_accuracy: 0.7697 - val_loss: 0.6225 - learning_rate: 0.0010
# Epoch 29/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8883 - loss: 0.3098 - val_accuracy: 0.7760 - val_loss: 0.6108 - learning_rate: 0.0010
# Epoch 30/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8741 - loss: 0.3199 - val_accuracy: 0.7902 - val_loss: 0.5874 - learning_rate: 0.0010
# Epoch 31/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8991 - loss: 0.2851 - val_accuracy: 0.7965 - val_loss: 0.5662 - learning_rate: 0.0010
# Epoch 32/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9005 - loss: 0.2735 - val_accuracy: 0.8060 - val_loss: 0.5396 - learning_rate: 0.0010
# Epoch 33/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9052 - loss: 0.2650 - val_accuracy: 0.8170 - val_loss: 0.5075 - learning_rate: 0.0010
# Epoch 34/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8944 - loss: 0.2958 - val_accuracy: 0.8060 - val_loss: 0.4991 - learning_rate: 0.0010
# Epoch 35/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8984 - loss: 0.2735 - val_accuracy: 0.8170 - val_loss: 0.4929 - learning_rate: 0.0010
# Epoch 36/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9018 - loss: 0.2515 - val_accuracy: 0.8249 - val_loss: 0.4825 - learning_rate: 0.0010
# Epoch 37/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9127 - loss: 0.2339 - val_accuracy: 0.8391 - val_loss: 0.4676 - learning_rate: 0.0010
# Epoch 38/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9059 - loss: 0.2575 - val_accuracy: 0.8375 - val_loss: 0.4662 - learning_rate: 0.0010
# Epoch 39/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9059 - loss: 0.2425 - val_accuracy: 0.8549 - val_loss: 0.4388 - learning_rate: 0.0010
# Epoch 40/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9235 - loss: 0.2224 - val_accuracy: 0.8391 - val_loss: 0.4388 - learning_rate: 0.0010
# Epoch 41/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9228 - loss: 0.2046 - val_accuracy: 0.8470 - val_loss: 0.4274 - learning_rate: 0.0010
# Epoch 42/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9235 - loss: 0.2094 - val_accuracy: 0.8722 - val_loss: 0.3849 - learning_rate: 0.0010
# Epoch 43/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9282 - loss: 0.1996 - val_accuracy: 0.8801 - val_loss: 0.3571 - learning_rate: 0.0010
# Epoch 44/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9201 - loss: 0.2128 - val_accuracy: 0.8785 - val_loss: 0.3548 - learning_rate: 0.0010
# Epoch 45/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9255 - loss: 0.1876 - val_accuracy: 0.8612 - val_loss: 0.3766 - learning_rate: 0.0010
# Epoch 46/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9357 - loss: 0.1785 - val_accuracy: 0.8849 - val_loss: 0.3289 - learning_rate: 0.0010
# Epoch 47/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9418 - loss: 0.1740 - val_accuracy: 0.9006 - val_loss: 0.2991 - learning_rate: 0.0010
# Epoch 48/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9357 - loss: 0.1758 - val_accuracy: 0.8943 - val_loss: 0.3033 - learning_rate: 0.0010
# Epoch 49/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9391 - loss: 0.1690 - val_accuracy: 0.8943 - val_loss: 0.3074 - learning_rate: 0.0010
# Epoch 50/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9350 - loss: 0.1743 - val_accuracy: 0.8991 - val_loss: 0.2986 - learning_rate: 0.0010
# Epoch 51/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9357 - loss: 0.1727 - val_accuracy: 0.9054 - val_loss: 0.2708 - learning_rate: 0.0010
# Epoch 52/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9438 - loss: 0.1648 - val_accuracy: 0.9132 - val_loss: 0.2522 - learning_rate: 0.0010
# Epoch 53/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9540 - loss: 0.1334 - val_accuracy: 0.9054 - val_loss: 0.2690 - learning_rate: 0.0010
# Epoch 54/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9411 - loss: 0.1590 - val_accuracy: 0.9101 - val_loss: 0.2539 - learning_rate: 0.0010
# Epoch 55/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9560 - loss: 0.1433 - val_accuracy: 0.9259 - val_loss: 0.2160 - learning_rate: 0.0010
# Epoch 56/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9485 - loss: 0.1387 - val_accuracy: 0.9369 - val_loss: 0.1977 - learning_rate: 0.0010
# Epoch 57/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9397 - loss: 0.1576 - val_accuracy: 0.9369 - val_loss: 0.1995 - learning_rate: 0.0010
# Epoch 58/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9519 - loss: 0.1313 - val_accuracy: 0.9322 - val_loss: 0.2012 - learning_rate: 0.0010
# Epoch 59/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9445 - loss: 0.1490 - val_accuracy: 0.9243 - val_loss: 0.2102 - learning_rate: 0.0010
# Epoch 60/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9580 - loss: 0.1307 - val_accuracy: 0.9306 - val_loss: 0.1970 - learning_rate: 5.0000e-04
# Epoch 61/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9485 - loss: 0.1398 - val_accuracy: 0.9353 - val_loss: 0.1928 - learning_rate: 5.0000e-04
# Epoch 62/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9506 - loss: 0.1389 - val_accuracy: 0.9353 - val_loss: 0.1834 - learning_rate: 5.0000e-04
# Epoch 63/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9601 - loss: 0.1224 - val_accuracy: 0.9416 - val_loss: 0.1752 - learning_rate: 5.0000e-04
# Epoch 64/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9634 - loss: 0.1153 - val_accuracy: 0.9448 - val_loss: 0.1691 - learning_rate: 5.0000e-04
# Epoch 65/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9546 - loss: 0.1291 - val_accuracy: 0.9495 - val_loss: 0.1629 - learning_rate: 5.0000e-04
# Epoch 66/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9445 - loss: 0.1440 - val_accuracy: 0.9479 - val_loss: 0.1610 - learning_rate: 5.0000e-04
# Epoch 67/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9573 - loss: 0.1175 - val_accuracy: 0.9479 - val_loss: 0.1652 - learning_rate: 5.0000e-04
# Epoch 68/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9621 - loss: 0.1102 - val_accuracy: 0.9511 - val_loss: 0.1597 - learning_rate: 5.0000e-04
# Epoch 69/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9560 - loss: 0.1243 - val_accuracy: 0.9495 - val_loss: 0.1562 - learning_rate: 5.0000e-04
# Epoch 70/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9445 - loss: 0.1334 - val_accuracy: 0.9448 - val_loss: 0.1517 - learning_rate: 5.0000e-04
# Epoch 71/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9573 - loss: 0.1191 - val_accuracy: 0.9495 - val_loss: 0.1486 - learning_rate: 5.0000e-04
# Epoch 72/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9526 - loss: 0.1190 - val_accuracy: 0.9527 - val_loss: 0.1510 - learning_rate: 5.0000e-04
# Epoch 73/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9607 - loss: 0.1135 - val_accuracy: 0.9511 - val_loss: 0.1574 - learning_rate: 5.0000e-04
# Epoch 74/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9648 - loss: 0.1030 - val_accuracy: 0.9511 - val_loss: 0.1533 - learning_rate: 5.0000e-04
# Epoch 75/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9668 - loss: 0.0958 - val_accuracy: 0.9558 - val_loss: 0.1501 - learning_rate: 2.5000e-04
# Epoch 76/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9655 - loss: 0.1059 - val_accuracy: 0.9558 - val_loss: 0.1455 - learning_rate: 2.5000e-04
# Epoch 77/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9641 - loss: 0.0907 - val_accuracy: 0.9590 - val_loss: 0.1416 - learning_rate: 2.5000e-04
# Epoch 78/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9601 - loss: 0.1130 - val_accuracy: 0.9590 - val_loss: 0.1380 - learning_rate: 2.5000e-04
# Epoch 79/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9628 - loss: 0.1184 - val_accuracy: 0.9574 - val_loss: 0.1366 - learning_rate: 2.5000e-04
# Epoch 80/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9601 - loss: 0.1148 - val_accuracy: 0.9574 - val_loss: 0.1351 - learning_rate: 2.5000e-04
# Epoch 81/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9641 - loss: 0.1152 - val_accuracy: 0.9574 - val_loss: 0.1369 - learning_rate: 2.5000e-04
# Epoch 82/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9661 - loss: 0.1048 - val_accuracy: 0.9574 - val_loss: 0.1359 - learning_rate: 2.5000e-04
# Epoch 83/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9661 - loss: 0.1061 - val_accuracy: 0.9574 - val_loss: 0.1343 - learning_rate: 2.5000e-04
# Epoch 84/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9655 - loss: 0.0975 - val_accuracy: 0.9590 - val_loss: 0.1331 - learning_rate: 2.5000e-04
# Epoch 85/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9587 - loss: 0.1164 - val_accuracy: 0.9606 - val_loss: 0.1319 - learning_rate: 2.5000e-04
# Epoch 86/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9661 - loss: 0.0966 - val_accuracy: 0.9574 - val_loss: 0.1332 - learning_rate: 2.5000e-04
# Epoch 87/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9648 - loss: 0.1057 - val_accuracy: 0.9558 - val_loss: 0.1337 - learning_rate: 2.5000e-04
# Epoch 88/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9634 - loss: 0.0998 - val_accuracy: 0.9558 - val_loss: 0.1339 - learning_rate: 2.5000e-04
# Epoch 89/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9682 - loss: 0.0907 - val_accuracy: 0.9527 - val_loss: 0.1344 - learning_rate: 1.2500e-04
# Epoch 90/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9628 - loss: 0.1029 - val_accuracy: 0.9527 - val_loss: 0.1353 - learning_rate: 1.2500e-04
# Epoch 91/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9621 - loss: 0.1087 - val_accuracy: 0.9527 - val_loss: 0.1355 - learning_rate: 1.2500e-04
# Epoch 92/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9607 - loss: 0.1115 - val_accuracy: 0.9543 - val_loss: 0.1351 - learning_rate: 6.2500e-05
# Epoch 93/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9580 - loss: 0.1251 - val_accuracy: 0.9543 - val_loss: 0.1348 - learning_rate: 6.2500e-05
# Epoch 94/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9479 - loss: 0.1374 - val_accuracy: 0.9543 - val_loss: 0.1346 - learning_rate: 6.2500e-05
# Epoch 95/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9628 - loss: 0.1052 - val_accuracy: 0.9543 - val_loss: 0.1349 - learning_rate: 3.1250e-05

# %%
test_loss, test_acc = model.evaluate(X_test_scaled, y_test, verbose=0)
print(f"Test accuracy: {test_acc:.4f}")

y_pred = model.predict(X_test_scaled)
y_pred_cls = y_pred.argmax(axis = 1)
# Out:
# Test accuracy: 0.9606
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
